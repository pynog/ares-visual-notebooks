# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import sys
sys.path.append(r"C:\Users\olivier\Documents\youpi\python-ares")


import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.tick(True, "Test")
aresObj.tick(False, "Live")
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssnumbercenter {width:100%; text-align:center; padding:0; font-size:18px; font-family:arial; margin-bottom:0; white-space:pre-wrap; font-weight:bold}
# </style>
# <div><div style="margin:5px 0">
#           <div id="tick_2629213749600" title="" style="font-size:14px;color:#293846;display:inline-block;width:20px" class="py_cssnumbercenter"></div>
#           <span style="height:100%;display:inline-block;padding-right:5px;margin-bottom:2px">Test</span>
#
#         </div>
#
#         <div style="margin:5px 0">
#           <div id="tick_2629490608504" title="" style="font-size:14px;color:#293846;display:inline-block;width:20px" class="py_cssnumbercenter"></div>
#           <span style="height:100%;display:inline-block;padding-right:5px;margin-bottom:2px">Live</span>
#
#         </div></div>
# <script>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.updown({'delta': 100, 'value': 24})
aresObj.updown({'delta': -10, 'value': 24})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="updown_2629490730880"  style="font-size:14px" class="py_cssdivnoborder"></div>
# <div id="updown_2629490731160"  style="font-size:14px" class="py_cssdivnoborder"></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.textbubble({"url": "", "title": "Python", 'value': 100, 'color': 'green'})
aresObj.display()
# Out:
# <style>
# .py_cssdivbox {width:100%}
# .py_cssdivbox:hover {border-left:4px solid #FFFFFF; background-color:#293846}
# .py_cssdivbubble {width:80px; margin-left:auto; margin-right:auto; height:80px; border-radius:50%; padding-top:20px; text-align:center; border:1px solid #808080}
# .py_csstitle {padding:0; font-size:18px; font-family:arial; margin-bottom:0; white-space:pre-wrap; font-weight:bold}
# </style>
# <div><div id="textbubble_2629490731048"  style="width:250px;padding-top:5px;margin-left:5px;text-align:center;background-color:#FFFFFF" class="py_cssdivbox"><div class="py_cssdivbubble py_csstitle" style="background-color:white;font-size:25pxpx"></div><div class="py_csstitle"><a style="text-decoration:none"></a></div></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.textborder({"title": "AReS", 'value': "A new Python Web Framework", 'color': 'green', 'icon': 'fab fa-python', 'colorTitle': 'darkgreen'})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstextwithborder fieldset {border:1px solid; padding:5px; margin:10px; background-color:#FFFFFF}
# </style>
# <div><div id="textwithborder_2629490731608"  style="width:None%;border-color:darkgreen;margin-top:20px;font-size:14px" class="py_csstextwithborder"><fieldset style="color:green"><i class="fab fa-python fa-5x" style="width:100%;text-align:center;margin:2px 0 10px 0;color:green"></i><legend style="font-size:24px;color:darkgreen"></legend><span></span></fieldset></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.vignet({'title': 'Python', 'number': 100, 'text': 'Ares new Python web framework', 'color': 'green', 'url': 'https://www.python.org/',
           'icon': 'fab fa-python', 'tooltip': 'Python Fondation', 'urlTitle': 'WebSite'})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.theme.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.structure.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" type="text/css">
# <style>
# .py_cssdivbox {width:100%}
# .py_cssdivbox:hover {border-left:4px solid #FFFFFF; background-color:#293846}
# .py_csstext {padding:0; font-family:arial; margin:0; font-size:14px}
# .py_cssnumbercenter {width:100%; text-align:center; padding:0; font-size:18px; font-family:arial; margin-bottom:0; white-space:pre-wrap; font-weight:bold}
# .py_csssdivboxmargin {margin:0; padding:0 2px 0 2px; font-family:arial; white-space:pre-wrap; border:1px solid #FFFFFF}
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.delta({'number': 100, 'prevNumber': 60, 'color': "", 'url': '', 'icon': '', 'tooltip': '', 'thresold1': 100, 'thresold2': 50})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="delta_2629490732840"  style="width:200px;height:80px;color:" class="py_cssdivnoborder">
#       <div style="width:100%;text-align:right;font-size:26px;"></div>
#       <div id="delta_2629490732840_progress" style="height:10px;color:"></div>
#       <div style="font-size:10px;font-style:italic;color:#404040;padding-bottom:5px;text-align:left"></div>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.light(True)
aresObj.light(False)
aresObj.light(None)
aresObj.display()
# Out:
# <style>
# .py_csssdivboxmargin {margin:0; padding:0 2px 0 2px; font-family:arial; white-space:pre-wrap; border:1px solid #FFFFFF}
# .py_csssdivboxmargin:hover {border:1px solid #293846}
# </style>
# <div><div id="trafficlight_2629490955768" title="" style="width:25px;height:25px;border-radius:50px;background-color:green;display:block" class="py_csssdivboxmargin"></div>
# <div id="trafficlight_2629490955992" title="" style="width:25px;height:25px;border-radius:50px;background-color:red;display:block" class="py_csssdivboxmargin"></div>
# <div id="trafficlight_2629490956160" title="" style="width:25px;height:25px;border-radius:50px;background-color:Orange;display:block" class="py_csssdivboxmargin"></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.textvignet({'text': 'This is an example', 'title': 'Title', 'icon': 'fab fa-accusoft'})
aresObj.display()
# Out:
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="textvignet_2629490956720"  style="color:#293846;padding-left:5px;margin-top:5px;text-align:justify;margin:auto" class="py_cssdivnoborder">
#         <div style="font-size:22px;color:#293846;width:100%;text-align:center"><i class="fab fa-accusoft" style="display-inline"></i>&nbsp;Title</div>
#         This is an example <br />
#         <div style="width:100%;text-align:right"><a href="#">+ more details</a></div>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...
