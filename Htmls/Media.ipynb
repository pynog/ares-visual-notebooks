# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import sys
sys.path.append(r"C:\Users\olivier\Documents\youpi\python-ares")

import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.youtube("https://youtu.be/mwGQfhYMPGA?t=224")
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_cssdivnoborder {margin:0; font-family:Calibri; clear:both; padding:0; border:0}
# </style>
# <div><div id="youtube_1644635094712"  style="width:100%" class="py_cssdivnoborder"><iframe width="420" height="315" type="text/html" src="https://youtu.be/mwGQfhYMPGA?t=224"> </iframe></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.audio("slot-machine-daniel_simon.mp3", path="http://soundbible.com/mp3")
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_cssdivnoborder {margin:0; font-family:Calibri; clear:both; padding:0; border:0}
# </style>
# <div><div id="audio_1644912399136"  style="width:100%" class="py_cssdivnoborder"><audio style="width:100%" controls autoplay></audio></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
path = "http://soundbible.com/mp3"
a = aresObj.audio("", path=path)
aresObj.button("Add").click(a.jsGenerate({'audio': "slot-machine-daniel_simon.mp3", 'path': path}, isPyData=True))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_cssdivnoborder {margin:0; font-family:Calibri; clear:both; padding:0; border:0}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# .py_cssbuttonbasic:focus {outline:0}
# </style>
# <div><div id="audio_1644912399640"  style="width:100%" class="py_cssdivnoborder"><audio style="width:100%" controls autoplay></audio></div>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.media("slot-machine-daniel_simon.mp3", path="http://soundbible.com/mp3")
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_cssdivnoborder {margin:0; font-family:Calibri; clear:both; padding:0; border:0}
# </style>
# <div><div id="media_1644635065200"  style="width:100%" class="py_cssdivnoborder"><video style="width:100%" controls></video></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...
