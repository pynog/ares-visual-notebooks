# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.div("Component 1").css({'border': '1px solid black'})
aresObj.div("Component 2").css({'border': '1px solid blue'})
aresObj.div("Component 3").css({'border': '1px solid red'})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="div_2511302384440"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid black" class="py_cssdivnoborder">Component 1</div>
# <div id="div_2511025273488"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid blue" class="py_cssdivnoborder">Component 2</div>
# <div id="div_2511302384720"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid red" class="py_cssdivnoborder">Component 3</div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.div("Component 1").css({'border': '1px solid black', 'margin': '5px'})
aresObj.div("Component 2").css({'border': '1px solid blue', 'margin': '5px'})
aresObj.div("Component 3").css({'border': '1px solid red', 'margin': '5px'})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="div_2511302488192"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid black;margin:5px" class="py_cssdivnoborder">Component 1</div>
# <div id="div_2511302488584"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid blue;margin:5px" class="py_cssdivnoborder">Component 2</div>
# <div id="div_2511302488640"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid red;margin:5px" class="py_cssdivnoborder">Component 3</div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
g = aresObj.grid([]) 
g + (aresObj.div("Component 1").css({'border': '1px solid black', 'margin': '5px'}), 4) # Sum col should be 12
g + (aresObj.div("Component 2").css({'border': '1px solid blue', 'margin': '5px'}), 4)
g + (aresObj.div("Component 3").css({'border': '1px solid red', 'margin': '5px'}), 4)
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="grid_2511302811944"  style="width:100%;overflow-x:hidden" class=""><div class="row"><div class="col-md-4 text-left"><div id="div_2511302812224"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid black;margin:5px" class="py_cssdivnoborder">Component 1</div></div><div class="col-md-4 text-left"><div id="div_2511302812392"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid blue;margin:5px" class="py_cssdivnoborder">Component 2</div></div><div class="col-md-4 text-left"><div id="div_2511302812504"  style="width:100%;color:black;font-size:14px;text-align:left;border:1px solid red;margin:5px" class="py_cssdivnoborder">Component 3</div></div></div></div></div>
# <script>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
c = aresObj.col([]) 
c + aresObj.div("Component 1").css({'border': '1px solid black', 'margin': '5px'})
c + aresObj.div("Component 2").css({'border': '1px solid blue', 'margin': '5px'})

g = aresObj.grid([])
g + (c, 8)
g + (aresObj.div("Component 3").css({'border': '1px solid red', 'margin': '5px'}), 4)
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
p = aresObj.panelsplit(height=100)
p.left(aresObj.div("Component 1").css({'border': '1px solid black', 'margin': '5px'}))
p.right(aresObj.div("Component 2").css({'border': '1px solid blue', 'margin': '5px'}))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
p = aresObj.paneldisplay(title="Click to hide / Show")
p + aresObj.div("Component 1").css({'border': '1px solid black', 'margin': '5px'})
p + aresObj.div("Component 2").css({'border': '1px solid blue', 'margin': '5px'})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# ...
