# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.table(aresObj.userconf('test_conf', mode='GET', delimiter='#', headerIdx=0, initialFile=r'C:\Users\nelso\PycharmProjects\ares-visual-notebooks\StaticConfig\test.txt'))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdn.datatables.net/buttons/1.5.2/css/buttons.bootstrap4.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/buttons/1.5.2/css/buttons.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/responsive/2.1.1/css/responsive.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/1.10.19/css/jquery.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivhidden {display:none}
# .py_cssdivtextleft {text-align:left}
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# ::selection {background:#e8f2ef}
# ::-moz-selection {background:#e8f2ef}
# ...

# %%
 aresObj.table_conf('table_conf_test', 'WEB', {'params': {'url': r'http://feeds.reuters.com/reuters/businessNews'}},
                     header={'title': {'title': 'Title'}, '_order': ['title']})  aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdn.datatables.net/buttons/1.5.2/css/buttons.bootstrap4.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/buttons/1.5.2/css/buttons.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/responsive/2.1.1/css/responsive.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdn.datatables.net/1.10.19/css/jquery.dataTables.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivhidden {display:none}
# .py_cssdivtextleft {text-align:left}
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# ::selection {background:#e8f2ef}
# ::-moz-selection {background:#e8f2ef}
# ...

# %%
# Out:
#                                                 title
# 0                              Reuters: Business News
# 1                                        Reuters News
# 2   Investor group calls on Lyft to scrap dual-cla...
# 3   Exclusive: Indian antitrust watchdog raids Gle...
# 4   Apple Watch detects irregular heart beat in la...
# 5   Amazon's second headquarters faces new blocks ...
# 6   Factbox: What we know about Boeing 737 MAX cra...
# 7   Airlines fear long grounding of Boeing 737 MAX...
# 8   BMW, Mercedes-Benz lower prices in China after...
# 9   Boeing 737 MAX software patch expected before ...
# 10  Apple infringed three Qualcomm patents, jury f...
# 11  PwC to pay $335 million over failed audits of ...
# 12  U.S. regulators want public's view on cars wit...
# 13  Take Five: Shall we try again? World markets t...
# 14  Wall Street weekahead: U.S. funds focus on med...
# 15  Russian metals tycoon Deripaska sues U.S. over...
# ...
