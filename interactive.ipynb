# %%
import sys

sys.path.append(r'C:\Users\olivier\Documents\youpi\python-ares')


# https://blog.dominodatalab.com/interactive-dashboards-in-jupyter/

# %%
from ares.Lib import Ares

aresObj = Ares.ReportAPI()
i = aresObj.input()
d = aresObj.text('')
i.enter(d.jsGenerate(i.val))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.theme.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.structure.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_csstext {padding:0; font-family:arial; margin:0; font-size:14px}
# </style>
# <div><div id="inputtext_2641160549488"  style="width:100%;height:27px;display:block;clear:both;vertical-align:middle" class="py_cssdivnoborder"><div style="height:100%;width:100%;"><input type="text"  placeholder="" class="form-control" value="" style="text-indent:0px;height:27px;width:100%"/></div></div>
# ...

# %%
from ares.Lib import Ares

aresObj = Ares.ReportAPI()
i = aresObj.input()
b = aresObj.button("Click Me!")
d = aresObj.text('')
b.click(d.jsGenerate(i.val))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.theme.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.structure.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# ...

# %%
from ares.Lib import Ares

aresObj = Ares.ReportAPI()
s = aresObj.slider(htmlCode='mySlider')
d = aresObj.text("0")
s.change([d.jsGenerate(s.val)])
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.theme.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.structure.min.css" type="text/css">
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.12.1/jquery-ui.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstext {padding:0; font-family:arial; margin:0; font-size:14px}
# </style>
# <div><div  style="width:100%;text-align:center;padding-top:-50px;padding:10px;margin-bottom:10px" >
#         <p style="width:100%;text-align:left;height:25px;margin-bottom:10px;font-size:14px;font-weight:bold;font-variant:small-caps;"></p>
#         <div style="width:100%;height:20px">
#           <span style="float:left;display:inline-block">0</span>
# ...
