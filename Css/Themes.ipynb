# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import ares.Lib.Ares as Ares

# Return the list of available themes
aresObj = Ares.ReportAPI()
print(aresObj.getThemes())
aresObj.display()
# Out:
# ['blue', 'blue-grey', 'green']
# <style>
#
# </style>
# <div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares

# Display the configuration of a theme
# if no name mentioned the default one is displayed
aresObj = Ares.ReportAPI()
aresObj.getTheme(name='green')
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstitle {padding:0; font-size:18px; font-family:arial; margin-bottom:0; white-space:pre-wrap; font-weight:bold}
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="title_2538285287240"  style="width:100%;margin-top:5px;color:#263238;display:inline-block" class="py_csstitle"><a class="anchorjs-link"></a></div>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.getTheme(category='colors')
aresObj.setColor("colors", 0, "yellow")
aresObj.getTheme(category='colors')
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstitle {padding:0; font-size:18px; font-family:arial; margin-bottom:0; white-space:pre-wrap; font-weight:bold}
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="title_2538285596568"  style="width:100%;margin-top:5px;color:#263238;display:inline-block" class="py_csstitle"><a class="anchorjs-link"></a></div>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.exportTheme() # Export the current theme used
aresObj.setTheme('bespoke', fileName='ThemeBespoke.py') # load the theme
aresObj.display()
# Out:
# <style>
#
# </style>
# <div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...
