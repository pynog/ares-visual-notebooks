# %%
import sys

sys.path.append(r"C:\Users\olivier\Documents\youpi\python-ares")

# %%
from ares.Lib import Ares


aresObj = Ares.ReportAPI()
df = aresObj.df({'dates': [1, 2], 'series': [3, 4]})
s = aresObj.select(df, dfColumn="series", htmlCode="test", globalFilter=True)
t = aresObj.table(df)
c = aresObj.chart('bar', df, seriesNames=['series'], xAxis='dates')
s.change([t.jsGenerate(None), c.jsGenerate(None)])  
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-select/1.13.0/css/bootstrap-select.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivhidden {display:none}
# .py_cssdivtextleft {text-align:left}
# .py_cssselect > select {margin:0; overflow:hidden; display:inline-block; background:#EBF0F8; color:#293846}
# .py_cssselect > select:hover {background:#293846; color:white}
# .py_cssselectstyle {font-weight:bold; font-size:16px; background:#384884; color:#FFFFFF}
# .py_cssdivloading {opacity:0.5; filter:alpha(opacity=50); width:100%; height:90%; text-align:center; padding-top:10%; color:#000008}
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# ...
