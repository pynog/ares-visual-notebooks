# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import sys
sys.path.append(r"C:\Users\olivier\Documents\youpi\python-ares")
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
d = aresObj.div("test", widthUnit='px').css({'border': '1px solid black', 'position':'relative', 'opacity':'0.2'})
aresObj.button("Animate").click(d.jsAnimate(100, "+=50"))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# </style>
# <div><div id="div_2584540665952"  style="width:100px;color:black;font-size:14px;text-align:left;border:1px solid black;position:relative;opacity:0.2" class="py_cssdivnoborder">test</div>
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_2584540462440"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
d = aresObj.div("test", widthUnit='px').css({'border': '1px solid black', 'position':'relative'})
aresObj.button("Animate").click([d.jsAnimate(100, left="+100px")])
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# </style>
# <div><div id="div_2584540664104"  style="width:100px;color:black;font-size:14px;text-align:left;border:1px solid black;position:relative" class="py_cssdivnoborder">test</div>
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_2584540665672"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
d = aresObj.div("test", widthUnit='px')
aresObj.button("Animate").click([d.jsAnimate(100, fontSize="30px")])
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# </style>
# <div><div id="div_2584540664552"  style="width:100px;color:black;font-size:14px;text-align:left" class="py_cssdivnoborder">test</div>
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_2584540667352"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
d = aresObj.div("test")
aresObj.button("Animate").click(d.jsSlideToggle(5000))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# </style>
# <div><div id="div_2584540462160"  style="width:100%;color:black;font-size:14px;text-align:left" class="py_cssdivnoborder">test</div>
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_2584540667520"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
# ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
d = aresObj.div("test")
aresObj.button("Animate").click(d.jsToggle(5000))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# .py_cssbuttonbasic {padding:1px 10px 5px 10px; margin:2px 0 2px 0; text-decoration:none; font-size:14px; border-radius:5px; display:inline-block; text-transform:uppercase; font-weight:bold; border:1px solid #293846; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#293846; color:#FFFFFF}
# </style>
# <div><div id="div_2584540666400"  style="width:100%;color:black;font-size:14px;text-align:left" class="py_cssdivnoborder">test</div>
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_2584540665448"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
# ...
