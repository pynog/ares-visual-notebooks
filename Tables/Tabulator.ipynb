# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
recordSet = {
    'dates': ['2019-01-01', '2019-01-01', '2019-01-10', '2019-01-11'],
    'category': ["ABCDEF", "ABCDEF", "DFCGHI", "GHIKLM"],
    'series': [3, 3, 4, 6],
    'series2': [5, 5, 1, 9],
    'series3': [3, 7, 3, 3],
    'selected': [True, False, True, True]}

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df({
    'dates': ['2019-01-01', '2019-01-01', '2019-01-10', '2019-01-11'],
    'category': ["ABCDEF", "ABCDEF", "DFCGHI", "GHIKLM"],
    'series': [3, 3, 4, 6],
    'series2': [5, 5, 1, 9],
    'series3': [3, 7, 3, 3]})
aresObj.tabulator(data)
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1974017684032"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1973737188808 = [{"category": "ABCDEF", "dates": "2019-01-01", "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "series": 6, "series2": 9, "series3": 3}];var args_1974017684480 = {} ;var datatabulator_1974017684032_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i>");text = text.replace(/__(.*?)__/g, "<u>$1</u>");text = text.replace(/~~ ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.abs(n - i).toFixed(decPlaces).slice(2) : "");
#   };
#
#   if (typeof Object.assign != 'function') {
#     Object.defineProperty(Object, "assign", {
#       value: function assign(target, varArgs) {
#         'use strict';
#         if (target == null) {
#           throw new TypeError('Cannot convert undefined or null to object')}
#         var to = Object(target);
#         for (var index = 1; index < arguments.length; index++) {
#           var nextSource = arguments[index];
#
#           if (nextSource != null) {
#             for (var nextKey in nextSource) {
#               if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                 to[nextKey] = nextSource[nextKey];
#               }
#             }
#           }
#         }
#         return to;
#       },
#       writa

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data,
        header={'category': {"editor": "select", "editorParams":{"Male":"male", "Female":"female"}},
                'dates': {'editor': 'input'},
                'series': {"editor": 'number'},
                'series2': {"formatter": "buttonCross", "align": "center", "cellClick": aresObj.jsConsole()},
                'selected': {'editor': 'tick', "formatter": "tickCross", 
                             "editorParams":{"tristate": True, "indeterminateValue": "n/a"} }})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1974017663328"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1974017663384 = {} ;var datatabulator_1974017663328_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.abs(n - i).toFixed(decPlaces).slice(2) : "");
#   };
#
#   if (typeof Object.assign != 'function') {
#     Object.defineProperty(Object, "assign", {
#       value: function assign(target, varArgs) {
#         'use strict';
#         if (target == null) {
#           throw new TypeError('Cannot convert undefined or null to object')}
#         var to = Object(target);
#         for (var index = 1; index < arguments.length; index++) {
#           var nextSource = arguments[index];
#
#           if (nextSource != null) {
#             for (var nextKey in nextSource) {
#               if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                 to[nextKey] = nextSource[nextKey];
#               }

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data)
aresObj.button('clear').click(tb.jsClear())
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1973737159648"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1973737322088"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1973737160656 = {} ;var datatabulator_1973737159648_markDownFnc = false;var button_1973737322088_data = "clear";var button_1973737322088_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/ ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator ==

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data)
# To change the column dates when series3 is clicked
tb.clickCol(tb.jsUpdateRow("{dates: Today()}"), ['series3'])
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1974017687224"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1974017685600 = {} ;var datatabulator_1974017687224_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.abs(n - i).toFixed(decPlaces).slice(2) : "");
#   };
#
#   if (typeof Object.assign != 'function') {
#     Object.defineProperty(Object, "assign", {
#       value: function assign(target, varArgs) {
#         'use strict';
#         if (target == null) {
#           throw new TypeError('Cannot convert undefined or null to object')}
#         var to = Object(target);
#         for (var index = 1; index < arguments.length; index++) {
#           var nextSource = arguments[index];
#
#           if (nextSource != null) {
#             for (var nextKey in nextSource) {
#               if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                 to[nextKey] = nextSource[nextKey];
#               }

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data)
aresObj.button('Add Row').click(tb2.jsAddRow({"category": 'Youpi'}, isPyData=True))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstablenewrow {color:#546472}
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1973737159816"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1973737159648"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1973737160488 = {} ;var datatabulator_1973737159816_markDownFnc = false;var button_1973737159648_data = "Add Row";var button_1973737159648_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data)
aresObj.button('Get Data').click(aresObj.jsConsole(tb.val))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1974017686272"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1974017685208"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1974017686608 = {} ;var datatabulator_1974017686272_markDownFnc = false;var button_1974017685208_data = "Get Data";var button_1974017685208_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replac ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data).setHeader(extraHeaders={"All Series": ["series", "series2", "series3"]})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator {border:1px solid #eeeeee}
# .py_csstabulatorheader .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:none; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:none; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1974017684872"  style="width:100%" class="py_csstabulatorheader py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1974017861024 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1973737159144 = {} ;var datatabulator_1974017684872_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.abs(n - i).toFixed(decPlaces).slice(2) : "");
#   };
#
#   if (typeof Object.assign != 'function') {
#     Object.defineProperty(Object, "assign", {
#       value: function assign(target, varArgs) {
#         'use strict';
#         if (target == null) {
#           throw new TypeError('Cannot convert undefined or null to object')}
#         var to = Object(target);
#         for (var index = 1; index < arguments.length; index++) {
#           var nextSource = arguments[index];
#
#           if (nextSource != null) {
#             for (var nextKey in nextSource) {
#               if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                 to[nextKey] = nextSource[nextKey];
#               }
