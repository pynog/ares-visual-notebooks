# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
recordSet = {
    'dates': ['2019-01-01', '2019-01-01', '2019-01-10', '2019-01-11'],
    'category': ["ABCDEF", "ABCDEF", "DFCGHI", "GHIKLM"],
    'series': [3, 3, 4, 6],
    'series2': [5, 5, 1, 9],
    'series3': [3, 7, 3, 3],
    'selected': [True, False, True, True]}

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df({
    'dates': ['2019-01-01', '2019-01-01', '2019-01-10', '2019-01-11'],
    'category': ["ABCDEF", "ABCDEF", "DFCGHI", "GHIKLM"],
    'series': [3, 3, 4, 6],
    'series2': [5, 5, 1, 9],
    'series3': [3, 7, 3, 3]})
aresObj.tabulator(data)
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424798096"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var recordset_1310424966704 = [{"category": "ABCDEF", "dates": "2019-01-01", "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "series": 6, "series2": 9, "series3": 3}];var args_1310424620560 = {} ;var datatabulator_1310424798096_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i>");text = text.replace(/__(.*?)__/g, "<u>$1</u>");text = text.replace(/~~ ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.ab

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data,
        header={'category': {"editor": "select", "editorParams":{"Male":"male", "Female":"female"}},
                'dates': {'editor': 'input'},
                'series': {"editor": 'number'},
                'series2': {"formatter": "buttonCross", "align": "center", "cellClick": aresObj.jsConsole()},
                'selected': {'editor': 'tick', "formatter": "tickCross", 
                             "editorParams":{"tristate": True, "indeterminateValue": "n/a"} }})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424462896"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310424463008 = {} ;var datatabulator_1310424462896_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data)
aresObj.button('clear').click(tb.jsClear())
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# .py_cssbuttonbasic:focus {outline:0}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310144033792"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1310143222336"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310144033288 = {} ;var datatabulator_1310144033792_markDownFnc = false;var button_1310143222336_data = "clear";var button_1310143222336_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/ ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb = aresObj.tabulator(data)
# To change the column dates when series3 is clicked
tb.clickCol(tb.jsUpdateRow("{dates: Today()}"), ['series3'])
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310143870792"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310143871968 = {} ;var datatabulator_1310143870792_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data)
aresObj.button('Add Row').click(tb2.jsAddRow({"category": 'Youpi'}, isPyData=True))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_csstablenewrow {color:#546472}
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# .py_cssbuttonbasic:focus {outline:0}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424462560"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1310424462056"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310424463848 = {} ;var datatabulator_1310424462560_markDownFnc = false;var button_1310424462056_data = "Add Row";var button_1310424462056_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data)
aresObj.button('Get Data').click(aresObj.jsConsole(tb.val))
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# .py_cssbuttonbasic {padding:1px 10px; margin:2px 0 2px 0; text-decoration:none; border-radius:5px; display:inline-block; font-weight:bold; border:1px solid #263238; color:#000000; background-color:#FFFFFF}
# .py_cssbuttonbasic:hover {text-decoration:none; cursor:pointer; background-color:#263238; color:#eceff1}
# .py_cssbuttonbasic:focus {outline:0}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424465192"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div>
#
# <div style="clear:both;width:100%;text-align:left"><button data-count=0 id="button_1310424463456"  style="height:26px" class="py_cssbuttonbasic" ></button></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'bootstrap': 'https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.bundle.min',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310424465304 = {} ;var datatabulator_1310424465192_markDownFnc = false;var button_1310424463456_data = "Get Data";var button_1310424463456_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replac ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data).setHeader(extraHeaders={"All Series": ["series", "series2", "series3"]})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424619272"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310424619384 = {} ;var datatabulator_1310424619272_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i> ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
data = aresObj.df(recordSet)
tb2 = aresObj.tabulator(data)
class MyStyle(object):
    __style = [
      {'attr': 'background-color', 'value': 'orange'},
    ]
css = aresObj.addPyCls(MyStyle)
aresObj.tabulator(data, title="title", header={
    "dates": {'cssClass': css.classname},
    "category": {},
    "category2": {}})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/css/tabulator.min.css" type="text/css">
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.1.0/css/all.css" type="text/css">
# <style>
# .py_mystyle {background-color:orange}
# .py_cssstandardlinks {color:#263238}
# .py_cssstandardlinks:hover {text-decoration:underline; text-decoration:underline; color:#000000}
# .py_csstabulator > div {border:1px solid #eeeeee; font-size:12px; background-color:#eeeeee; font-family:Calibri}
# .py_csstabulatorcol .tabulator-col {text-align:center !IMPORTANT; color:#000000; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorevenrow .tabulator-row-even {color:#000000; border:1px solid #cfd8dc !IMPORTANT; background-color:#cfd8dc}
# .py_csstabulatorrow .tabulator-row {text-align:center !IMPORTANT}
# .py_csstabulatorrow .tabulator-row:hover {color:#000000; border:1px solid #C00000 !IMPORTANT; background-color:#90a4ae}
# .py_csstabulatoroddrow .tabulator-row-odd {color:#000000; border:1px solid #FFFFFF !IMPORTANT; background-color:#FFFFFF}
# .py_csstabulatorfooter .tabulator-footer {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled) {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorfooterpagination .tabulator-page:not(.disabled):hover {color:#eceff1 !IMPORTANT; background:#263238 !IMPORTANT}
# .py_csstabulatorheader .tabulator-header {color:#000000 !IMPORTANT; border:none !IMPORTANT; background:#FFFFFF !IMPORTANT}
# .py_csstabulatorhover:hover {border:1px solid #C00000}
# .py_csstitle4 {padding:0; font-size:14px; margin-top:5px; font-weight:bold; text-transform:uppercase; white-space:pre-wrap}
# </style>
# <div><div class="py_csstitle4"></div>
#       <div id="datatabulator_1310424619832"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div>
#
#
#       <div class="py_csstitle4">title</div>
#       <div id="datatabulator_1310424619104"  style="width:100%;margin-bottom:5px" class="py_csstabulatorcol py_csstabulatorevenrow py_csstabulatorrow py_csstabulatoroddrow py_csstabulator py_csstabulatorfooter py_csstabulatorfooterpagination py_csstabulatorheader py_csstabulatorhover"></div></div>
# <script>
# require.config({ paths: {'fontawesome': 'https://use.fontawesome.com/releases/v5.1.0/js/fontawesome',
#   'tabulator': 'https://cdnjs.cloudflare.com/ajax/libs/tabulator/4.1.5/js/tabulator.min',
#   'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var recordset_1310144023360 = [{"category": "ABCDEF", "dates": "2019-01-01", "selected": true, "series": 3, "series2": 5, "series3": 3}, {"category": "ABCDEF", "dates": "2019-01-01", "selected": false, "series": 3, "series2": 5, "series3": 7}, {"category": "DFCGHI", "dates": "2019-01-10", "selected": true, "series": 4, "series2": 1, "series3": 3}, {"category": "GHIKLM", "dates": "2019-01-11", "selected": true, "series": 6, "series2": 9, "series3": 3}];var args_1310424463176 = {} ;var datatabulator_1310424619832_markDownFnc = false;var args_1310424462840 = {} ;var datatabulator_1310424619104_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#263238', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\* ...
#   Boolean.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) { return this};
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
