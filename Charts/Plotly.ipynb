# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.externallink({'text': 'More examples on the Official Website', 'url': 'https://plot.ly/javascript/'})
aresObj.display()
# Out:
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="externallink_2624441810616"   class="py_cssdivnoborder"><a target="_blank" style="text-decoration:none"></a></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
# ...

# %%
import ares.Lib.Ares as Ares
import random

step = 10
series = 5
xAxisCat = ['A', 'B', 'C', 'D', 'E']

aresObj = Ares.ReportAPI()

recordSet = {'categories': [xAxisCat[int(random.random()*100) % len(xAxisCat)] for i in range(step)]}
for i in range(series):
    recordSet["col%s" % i] = [random.random()*100 for _ in range(step)]

    # Create an AReS DataFrame from the python dictionary
df = aresObj.df(recordSet)
aresObj.chart('pie', df, title='Pie Chart', seriesNames=['col2'], xAxis='categories', htmlCode='ChartLine', chartFamily='Plotly')
aresObj.chart('bar', df, seriesNames=['col0', 'col1'], xAxis='categories', htmlCode='ChartBar', chartFamily='Plotly')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="ChartLine_container">
#         <div id="ChartLine" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="ChartLine_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div>
#
#
#       <div  style="width:100%;height:300px" class="py_cssdivchart" id="ChartBar_container">
#         <div id="ChartBar" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="ChartBar_time" style="display:inline-block"></div>
# ...

# %%
import ares.Lib.Ares as Ares
import random

aresObj = Ares.ReportAPI()
df1 = aresObj.df({'col2': [random.random() for i in range(step)], 'col3': [random.random() for i in range(step)], 'col4': [random.random() for i in range(step)]})
aresObj.chart('line3d', df1, seriesNames=['col3', 'col2'], xAxis='col4', otherDims=['col3'], chartFamily='Plotly')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="chart_2624719025936_container">
#         <div id="chart_2624719025936" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2624719025936_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'Plotly': 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.43.1/plotly.min'} });
# ...

# %%
import ares.Lib.Ares as Ares
import random

aresObj = Ares.ReportAPI()
df1 = aresObj.df({'col2': [random.random() for i in range(step)], 'col3': [random.random() for i in range(step)], 'col4': [random.random() for i in range(step)]})
aresObj.chart('box', df1, seriesNames=['col2', 'col3'], xAxis='col4', htmlCode='Chart', chartFamily='Plotly')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="Chart_container">
#         <div id="Chart" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="Chart_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'Plotly': 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.43.1/plotly.min'} });
# ...

# %%
import ares.Lib.Ares as Ares
import random

aresObj = Ares.ReportAPI()
df1 = aresObj.df({'col2': [random.random() for i in range(step)], 'col3': [random.random() for i in range(step)], 'col4': [random.random() for i in range(step)]})
aresObj.chart('parcoords', df1, seriesNames=['col2', 'col3', 'col4'], xAxis='_index')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="chart_2624726226256_container">
#         <div id="chart_2624726226256" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2624726226256_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'Plotly': 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.43.1/plotly.min'} });
# ...

# %%
import ares.Lib.Ares as Ares
import random

aresObj = Ares.ReportAPI()
df1 = aresObj.df({'col2': [random.random() for i in range(step)], 'col3': [random.random() for i in range(step)], 'col4': [random.random() for i in range(step)]})
aresObj.chart('choropleth', df1, seriesNames=['col2', 'col3', 'col4'], xAxis='_index')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="chart_2624726224968_container">
#         <div id="chart_2624726224968" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2624726224968_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'Plotly': 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.43.1/plotly.min'} });
# ...

# %%
import ares.Lib.Ares as Ares
import random

aresObj = Ares.ReportAPI()
df1 = aresObj.df({'col2': [random.random() for i in range(step)], 'col3': [random.random() for i in range(step)], 'col4': [random.random() for i in range(step)]})
aresObj.chart('europe', df1, seriesNames=['col2', 'col3', 'col4'], xAxis='_index')
aresObj.display()
# Out:
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px" class="py_cssdivchart" id="chart_2624726228104_container">
#         <div id="chart_2624726228104" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2624726228104_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'Plotly': 'https://cdnjs.cloudflare.com/ajax/libs/plotly.js/1.43.1/plotly.min'} });
# ...
