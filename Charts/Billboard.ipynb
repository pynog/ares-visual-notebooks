# %% [markdown]
# <img align="left" src="../Ares_PetitIcon.PNG">

# %%
import sys
sys.path.append(r"C:\Users\olivier\Documents\youpi\python-ares")


import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
aresObj.externallink({'text': 'More examples on the Official Website', 'url': 'https://naver.github.io/billboard.js/'})
aresObj.display()
# Out:
# <style>
# .py_cssdivnoborder {margin:0; font-family:arial; clear:both; padding:0; border:0; outline:none}
# </style>
# <div><div id="externallink_2010407825360"   class="py_cssdivnoborder"><a target="_blank" style="text-decoration:none"></a></div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min'} });
#  var externallink_2010407825360_data = {"text": "More examples on the Official Website", "url": "https://naver.github.io/billboard.js/", "isJs": false};var externallink_2010407825360_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { window.clipboardData.setData('Text', url + '?' + params); }else {var selection = window.getSelection();$("body").append("<div id='breadcrumb_url'>"+ url + '?' + params +"</div>");var range = document.createRange();range.selectNodeContents($('#breadcrumb_url').get(0));selection.removeAllRanges(); selection.addRange(range);document.execCommand("Copy") ; $('#breadcrumb_url').remove() ;var div = $('<div>Report Parameters copied to ClickBoard !</div>').css({'display': 'block', 'position': 'fixed', 'top': '40px', 'right': '200px','text-align': 'center', 'padding': '5px', 'color': 'white', 'border-radius': '.4em', 'z-index': 10010, 'background-color': '#293846', "width": '200px'});$('body').append(div); setTimeout(function() {div.remove()}, 2000) } ;};function FormGoTo(url, method) { var form = $('<form method="'+ method +'" action='+ url +'></form>') ; NO_UNLOAD = true;for(var key in breadCrumUrl['params']) {form.append( '<input type="hidden" name="'+ key +'" value="' + breadCrumUrl['params'][key] + '">' ) } ;form.appendTo('body').submit(); ;};function toAresMarkup(text) { text = text.replace(/\*\*(.*?)\*\*/g, "<b>$1</b>");text = text.replace(/\*\*\*(.*?)\*\*\*/g, "<b><i>$1</i></b>");text = text.replace(/\*(.*?)\*/g, "<i>$1</i>");text = text.replace(/__(.*?)__/g, "<u>$1</u>");text = text.replace(/~~(.*?)~~/g, "<i>$1</i>");text = text.replace(/--(.*?)--/g, "<del>$1</del>");text = text.replace(/<<(.*?)>>/g, "<a href='$1'>Link</a>");text = text.replace(/\!\((.*?)\)/g, "<i class='$1'></i>");text = text.replace(/\[(.*?)\]\(https\\:(.*?)\)/g, "<a href='$2' targe ...
#   Number.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = this, decPlaces = isNaN(decPlaces = Math.abs(decPlaces)) ? 2 : decPlaces,
#         decSeparator = decSeparator == undefined ? "." : decSeparator,
#         thouSeparator = thouSeparator == undefined ? "," : thouSeparator,
#         sign = n < 0 ? "-" : "",
#         i = parseInt(n = Math.abs(+n || 0).toFixed(decPlaces)) + "",
#         j = (j = i.length) > 3 ? j % 3 : 0;
#     return sign + (j ? i.substr(0, j) + thouSeparator : "") + i.substr(j).replace(/(\d{3})(?=\d)/g, "$1" + thouSeparator) + (decPlaces ? decSeparator + Math.abs(n - i).toFixed(decPlaces).slice(2) : "");
#   };
#
#   if (typeof Object.assign != 'function') {
#     Object.defineProperty(Object, "assign", {
#       value: function assign(target, varArgs) {
#         'use strict';
#         if (target == null) {
#           throw new TypeError('Cannot convert undefined or null to object')}
#         var to = Object(target);
#         for (var index = 1; index < arguments.length; index++) {
#           var nextSource = arguments[index];
#
#           if (nextSource != null) {
#             for (var nextKey in nextSource) {
#               if (Object.prototype.hasOwnProperty.call(nextSource, nextKey)) {
#                 to[nextKey] = nextSource[nextKey];
#               }
#             }
#           }
#         }
#         return to;
#       },
#       writable: true,
#       configurable: true
#     });
#   }
#
#   String.prototype.formatMoney = function(decPlaces, thouSeparator, decSeparator) {
#     var n = parseFloat(this); return n.formatMoney(decPlaces, thouSeparator, decSeparator);
#   };
#   var breadCrumUrl = {url: "", params: {} } ;;
# $(document).ready(function() { require(['jquery'], function (jquery) {
# $('#footer').css('margin-left', '-35px')
# $('#ares_page_content').css('margin-left', '-35px')
#
#       externallink_2010407825360_data['params'] = {  } ;
#       ExternalLink($('#externallink_2010407825360 a'), externallink_2010407825360_data) ;
#        }) })
# </script>

# %%
import random

step = 10
series = 5
xAxisCat = ['A', 'B', 'C', 'D', 'E']
recordSet = {'categories': [xAxisCat[int(random.random()*100) % len(xAxisCat)] for i in range(step)]}
for i in range(series):
    recordSet["col%s" % i] = [random.random()*100 for _ in range(step)]

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
df = aresObj.df(recordSet)
aresObj.chart('line', df, title='Line Chart', seriesNames=['col1', 'col2'], xAxis='categories', chartFamily='Billboard', chartOptions={'legend': {'show': False}})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min.css" type="text/css">
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px;padding:5px;position:relative" class="py_cssdivchart" id="chart_2010369024128_container">
#         <div id="chart_2010369024128_div" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2010369024128_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'd3-tip': 'https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.9.1/d3-tip.min',
#   'd3_color': 'https://cdnjs.cloudflare.com/ajax/libs/d3-color/1.2.1/d3-color.min',
#   'd3_time_format': 'https://cdnjs.cloudflare.com/ajax/libs/d3-time-format/2.1.1/d3-time-format.min',
#   'd3_shape': 'https://cdnjs.cloudflare.com/ajax/libs/d3-shape/1.2.0/d3-shape.min',
#   'd3_zoom': 'https://cdnjs.cloudflare.com/ajax/libs/d3-zoom/1.7.1/d3-zoom.min',
#   'd3_dsv': 'https://cdnjs.cloudflare.com/ajax/libs/d3-dsv/1.0.8/d3-dsv.min',
#   'd3_ease': 'https://cdnjs.cloudflare.com/ajax/libs/d3-ease/1.0.3/d3-ease.min',
#   'd3_scale': 'https://cdnjs.cloudflare.com/ajax/libs/d3-scale/1.0.7/d3-scale.min',
#   'd3_brush': 'https://cdnjs.cloudflare.com/ajax/libs/d3-brush/1.0.4/d3-brush.min',
#   'd3_selection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-selection/1.2.0/d3-selection.min',
#   'd3_transition': 'https://cdnjs.cloudflare.com/ajax/libs/d3-transition/1.1.1/d3-transition.min',
#   'd3_array': 'https://cdnjs.cloudflare.com/ajax/libs/d3-array/1.2.2/d3-array.min',
#   'd3_collection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-collection/1.0.5/d3-collection.min',
#   'd3_drag': 'https://cdnjs.cloudflare.com/ajax/libs/d3-drag/1.2.1/d3-drag.min',
#   'd3_interpolate': 'https://cdnjs.cloudflare.com/ajax/libs/d3-interpolate/1.3.0/d3-interpolate.min',
#   'd3_axis': 'https://cdnjs.cloudflare.com/ajax/libs/d3-axis/1.0.10/d3-axis.min',
#   'bb': 'https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min'} });
#  var recordset_2010407952456 = [{"categories": "A", "col0": 33.963100720747484, "col1": 56.94191086997672, "col2": 9.581599778973882, "col3": 50.870405514757586, "col4": 12.321938218946505}, {"categories": "A", "col0": 38.70968312781851, "col1": 66.48380078463465, "col2": 59.71512415170164, "col3": 18.27929352184654, "col4": 66.53567010320992}, {"categories": "B", "col0": 51.03252843372263, "col1": 63.65101989806373, "col2": 42.80192024372096, "col3": 15.493028384605767, "col4": 1.8510115206590183}, {"categories": "B", "col0": 36.18459906904743, "col1": 8.38438469923749, "col2": 86.17082993712, "col3": 68.88258891676287, "col4": 91.39174885371808}, {"categories": "D", "col0": 69.39995804205992, "col1": 24.115653511146718, "col2": 48.374862754809776, "col3": 87.79895135035206, "col4": 26.14370797750717}, {"categories": "D", "col0": 94.24344589059334, "col1": 90.13135136130028, "col2": 80.44625317489727, "col3": 22.6043232147787, "col4": 93.40477296593345}, {"categories": "D", "col0": 8.854183492033973, "col1": 93.08511206959147, "col2": 34.172310220681155, "col3": 72.50318223798608, "col4": 59.07520153841682}, {"categories": "E", "col0": 94.34365450014978, "col1": 35.02130986226719, "col2": 54.72099793040287, "col3": 5.855012356539269, "col4": 25.616153554561084}, {"categories": "E", "col0": 31.3163302007912, "col1": 94.37203879424804, "col2": 43.702068017586015, "col3": 54.765061835585946, "col4": 18.655317988093177}, {"categories": "E", "col0": 39.99639850196722, "col1": 87.46614082051879, "col2": 51.176152537308326, "col3": 14.587946006175411, "col4": 38.72964910916236}];var args_2010685161880 = {"keys_0": ["categories"], "values_0": ["col1", "col2"], "chart_0_1": ["col1", "col2"], "chart_1_1": "categories"} ;var chart_2010369024128_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardDa ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
df = aresObj.df(recordSet)
aresObj.chart('area', df, seriesNames=['col0', 'col3'], xAxis='categories', chartFamily='Billboard', chartOptions={'legend': {'show': False}})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min.css" type="text/css">
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px;padding:5px;position:relative" class="py_cssdivchart" id="chart_2010688836216_container">
#         <div id="chart_2010688836216_div" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2010688836216_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'd3-tip': 'https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.9.1/d3-tip.min',
#   'd3_color': 'https://cdnjs.cloudflare.com/ajax/libs/d3-color/1.2.1/d3-color.min',
#   'd3_time_format': 'https://cdnjs.cloudflare.com/ajax/libs/d3-time-format/2.1.1/d3-time-format.min',
#   'd3_shape': 'https://cdnjs.cloudflare.com/ajax/libs/d3-shape/1.2.0/d3-shape.min',
#   'd3_zoom': 'https://cdnjs.cloudflare.com/ajax/libs/d3-zoom/1.7.1/d3-zoom.min',
#   'd3_dsv': 'https://cdnjs.cloudflare.com/ajax/libs/d3-dsv/1.0.8/d3-dsv.min',
#   'd3_ease': 'https://cdnjs.cloudflare.com/ajax/libs/d3-ease/1.0.3/d3-ease.min',
#   'd3_scale': 'https://cdnjs.cloudflare.com/ajax/libs/d3-scale/1.0.7/d3-scale.min',
#   'd3_brush': 'https://cdnjs.cloudflare.com/ajax/libs/d3-brush/1.0.4/d3-brush.min',
#   'd3_selection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-selection/1.2.0/d3-selection.min',
#   'd3_transition': 'https://cdnjs.cloudflare.com/ajax/libs/d3-transition/1.1.1/d3-transition.min',
#   'd3_array': 'https://cdnjs.cloudflare.com/ajax/libs/d3-array/1.2.2/d3-array.min',
#   'd3_collection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-collection/1.0.5/d3-collection.min',
#   'd3_drag': 'https://cdnjs.cloudflare.com/ajax/libs/d3-drag/1.2.1/d3-drag.min',
#   'd3_interpolate': 'https://cdnjs.cloudflare.com/ajax/libs/d3-interpolate/1.3.0/d3-interpolate.min',
#   'd3_axis': 'https://cdnjs.cloudflare.com/ajax/libs/d3-axis/1.0.10/d3-axis.min',
#   'bb': 'https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min'} });
#  var recordset_2010407952456 = [{"categories": "A", "col0": 33.963100720747484, "col1": 56.94191086997672, "col2": 9.581599778973882, "col3": 50.870405514757586, "col4": 12.321938218946505}, {"categories": "A", "col0": 38.70968312781851, "col1": 66.48380078463465, "col2": 59.71512415170164, "col3": 18.27929352184654, "col4": 66.53567010320992}, {"categories": "B", "col0": 51.03252843372263, "col1": 63.65101989806373, "col2": 42.80192024372096, "col3": 15.493028384605767, "col4": 1.8510115206590183}, {"categories": "B", "col0": 36.18459906904743, "col1": 8.38438469923749, "col2": 86.17082993712, "col3": 68.88258891676287, "col4": 91.39174885371808}, {"categories": "D", "col0": 69.39995804205992, "col1": 24.115653511146718, "col2": 48.374862754809776, "col3": 87.79895135035206, "col4": 26.14370797750717}, {"categories": "D", "col0": 94.24344589059334, "col1": 90.13135136130028, "col2": 80.44625317489727, "col3": 22.6043232147787, "col4": 93.40477296593345}, {"categories": "D", "col0": 8.854183492033973, "col1": 93.08511206959147, "col2": 34.172310220681155, "col3": 72.50318223798608, "col4": 59.07520153841682}, {"categories": "E", "col0": 94.34365450014978, "col1": 35.02130986226719, "col2": 54.72099793040287, "col3": 5.855012356539269, "col4": 25.616153554561084}, {"categories": "E", "col0": 31.3163302007912, "col1": 94.37203879424804, "col2": 43.702068017586015, "col3": 54.765061835585946, "col4": 18.655317988093177}, {"categories": "E", "col0": 39.99639850196722, "col1": 87.46614082051879, "col2": 51.176152537308326, "col3": 14.587946006175411, "col4": 38.72964910916236}];var args_2010688835992 = {"keys_0": ["categories"], "values_0": ["col0", "col3"], "chart_0_1": ["col0", "col3"], "chart_1_1": "categories"} ;var chart_2010688836216_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardDa ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
df = aresObj.df(recordSet)
aresObj.chart('radar', df, seriesNames=['col3', 'col2'], xAxis='categories', chartFamily='Billboard', chartOptions={'legend': {'show': False}})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min.css" type="text/css">
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px;padding:5px;position:relative" class="py_cssdivchart" id="chart_2010688837448_container">
#         <div id="chart_2010688837448_div" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="chart_2010688837448_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'd3-tip': 'https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.9.1/d3-tip.min',
#   'd3_color': 'https://cdnjs.cloudflare.com/ajax/libs/d3-color/1.2.1/d3-color.min',
#   'd3_time_format': 'https://cdnjs.cloudflare.com/ajax/libs/d3-time-format/2.1.1/d3-time-format.min',
#   'd3_shape': 'https://cdnjs.cloudflare.com/ajax/libs/d3-shape/1.2.0/d3-shape.min',
#   'd3_zoom': 'https://cdnjs.cloudflare.com/ajax/libs/d3-zoom/1.7.1/d3-zoom.min',
#   'd3_dsv': 'https://cdnjs.cloudflare.com/ajax/libs/d3-dsv/1.0.8/d3-dsv.min',
#   'd3_ease': 'https://cdnjs.cloudflare.com/ajax/libs/d3-ease/1.0.3/d3-ease.min',
#   'd3_scale': 'https://cdnjs.cloudflare.com/ajax/libs/d3-scale/1.0.7/d3-scale.min',
#   'd3_brush': 'https://cdnjs.cloudflare.com/ajax/libs/d3-brush/1.0.4/d3-brush.min',
#   'd3_selection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-selection/1.2.0/d3-selection.min',
#   'd3_transition': 'https://cdnjs.cloudflare.com/ajax/libs/d3-transition/1.1.1/d3-transition.min',
#   'd3_array': 'https://cdnjs.cloudflare.com/ajax/libs/d3-array/1.2.2/d3-array.min',
#   'd3_collection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-collection/1.0.5/d3-collection.min',
#   'd3_drag': 'https://cdnjs.cloudflare.com/ajax/libs/d3-drag/1.2.1/d3-drag.min',
#   'd3_interpolate': 'https://cdnjs.cloudflare.com/ajax/libs/d3-interpolate/1.3.0/d3-interpolate.min',
#   'd3_axis': 'https://cdnjs.cloudflare.com/ajax/libs/d3-axis/1.0.10/d3-axis.min',
#   'bb': 'https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min'} });
#  var recordset_2010407952456 = [{"categories": "A", "col0": 33.963100720747484, "col1": 56.94191086997672, "col2": 9.581599778973882, "col3": 50.870405514757586, "col4": 12.321938218946505}, {"categories": "A", "col0": 38.70968312781851, "col1": 66.48380078463465, "col2": 59.71512415170164, "col3": 18.27929352184654, "col4": 66.53567010320992}, {"categories": "B", "col0": 51.03252843372263, "col1": 63.65101989806373, "col2": 42.80192024372096, "col3": 15.493028384605767, "col4": 1.8510115206590183}, {"categories": "B", "col0": 36.18459906904743, "col1": 8.38438469923749, "col2": 86.17082993712, "col3": 68.88258891676287, "col4": 91.39174885371808}, {"categories": "D", "col0": 69.39995804205992, "col1": 24.115653511146718, "col2": 48.374862754809776, "col3": 87.79895135035206, "col4": 26.14370797750717}, {"categories": "D", "col0": 94.24344589059334, "col1": 90.13135136130028, "col2": 80.44625317489727, "col3": 22.6043232147787, "col4": 93.40477296593345}, {"categories": "D", "col0": 8.854183492033973, "col1": 93.08511206959147, "col2": 34.172310220681155, "col3": 72.50318223798608, "col4": 59.07520153841682}, {"categories": "E", "col0": 94.34365450014978, "col1": 35.02130986226719, "col2": 54.72099793040287, "col3": 5.855012356539269, "col4": 25.616153554561084}, {"categories": "E", "col0": 31.3163302007912, "col1": 94.37203879424804, "col2": 43.702068017586015, "col3": 54.765061835585946, "col4": 18.655317988093177}, {"categories": "E", "col0": 39.99639850196722, "col1": 87.46614082051879, "col2": 51.176152537308326, "col3": 14.587946006175411, "col4": 38.72964910916236}];var args_2010684938672 = {"keys_0": ["categories"], "values_0": ["col3", "col2"], "chart_0_1": ["col3", "col2"], "chart_1_1": "categories"} ;var chart_2010688837448_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardDa ...

# %%
import ares.Lib.Ares as Ares

aresObj = Ares.ReportAPI()
df = aresObj.df(recordSet)
aresObj.chart('bubble', df, seriesNames=['col0', 'col1'], xAxis='categories', chartFamily='Billboard', globalFilter=True, htmlCode='ChartBubble', chartOptions={'legend': {'show': False}})
aresObj.display()
# Out:
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min.css" type="text/css">
# <style>
# .py_cssdivchart {margin:0 0 5px 0; padding:5px; outline:none; border:1px solid #F4F4F4}
# .py_cssdivchart:hover {border:1px solid #6285b0}
# </style>
# <div><div  style="width:100%;height:300px;padding:5px;position:relative" class="py_cssdivchart" id="ChartBubble_container">
#         <div id="ChartBubble_div" style="height:270px"></div>
#         <span style="bottom:0;margin:0 0 5px 0;width:100%">
#           <i style="margin:0 5px 0 0" class="fas fa-clock"></i>Last update: <div id="ChartBubble_time" style="display:inline-block"></div>
#           <div style="display:inline-block;float:right;margin-right:0px">
#
#           </div>
#         </span>
#       </div></div>
# <script>
# require.config({ paths: {'jquery': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.3.1/jquery.min',
#   'd3': 'https://cdnjs.cloudflare.com/ajax/libs/d3/5.7.0/d3.min',
#   'd3-tip': 'https://cdnjs.cloudflare.com/ajax/libs/d3-tip/0.9.1/d3-tip.min',
#   'd3_color': 'https://cdnjs.cloudflare.com/ajax/libs/d3-color/1.2.1/d3-color.min',
#   'd3_time_format': 'https://cdnjs.cloudflare.com/ajax/libs/d3-time-format/2.1.1/d3-time-format.min',
#   'd3_shape': 'https://cdnjs.cloudflare.com/ajax/libs/d3-shape/1.2.0/d3-shape.min',
#   'd3_zoom': 'https://cdnjs.cloudflare.com/ajax/libs/d3-zoom/1.7.1/d3-zoom.min',
#   'd3_dsv': 'https://cdnjs.cloudflare.com/ajax/libs/d3-dsv/1.0.8/d3-dsv.min',
#   'd3_ease': 'https://cdnjs.cloudflare.com/ajax/libs/d3-ease/1.0.3/d3-ease.min',
#   'd3_scale': 'https://cdnjs.cloudflare.com/ajax/libs/d3-scale/1.0.7/d3-scale.min',
#   'd3_brush': 'https://cdnjs.cloudflare.com/ajax/libs/d3-brush/1.0.4/d3-brush.min',
#   'd3_selection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-selection/1.2.0/d3-selection.min',
#   'd3_transition': 'https://cdnjs.cloudflare.com/ajax/libs/d3-transition/1.1.1/d3-transition.min',
#   'd3_array': 'https://cdnjs.cloudflare.com/ajax/libs/d3-array/1.2.2/d3-array.min',
#   'd3_collection': 'https://cdnjs.cloudflare.com/ajax/libs/d3-collection/1.0.5/d3-collection.min',
#   'd3_drag': 'https://cdnjs.cloudflare.com/ajax/libs/d3-drag/1.2.1/d3-drag.min',
#   'd3_interpolate': 'https://cdnjs.cloudflare.com/ajax/libs/d3-interpolate/1.3.0/d3-interpolate.min',
#   'd3_axis': 'https://cdnjs.cloudflare.com/ajax/libs/d3-axis/1.0.10/d3-axis.min',
#   'bb': 'https://cdnjs.cloudflare.com/ajax/libs/billboard.js/1.7.1/billboard.min'} });
#  var recordset_2010407952456 = [{"categories": "A", "col0": 33.963100720747484, "col1": 56.94191086997672, "col2": 9.581599778973882, "col3": 50.870405514757586, "col4": 12.321938218946505}, {"categories": "A", "col0": 38.70968312781851, "col1": 66.48380078463465, "col2": 59.71512415170164, "col3": 18.27929352184654, "col4": 66.53567010320992}, {"categories": "B", "col0": 51.03252843372263, "col1": 63.65101989806373, "col2": 42.80192024372096, "col3": 15.493028384605767, "col4": 1.8510115206590183}, {"categories": "B", "col0": 36.18459906904743, "col1": 8.38438469923749, "col2": 86.17082993712, "col3": 68.88258891676287, "col4": 91.39174885371808}, {"categories": "D", "col0": 69.39995804205992, "col1": 24.115653511146718, "col2": 48.374862754809776, "col3": 87.79895135035206, "col4": 26.14370797750717}, {"categories": "D", "col0": 94.24344589059334, "col1": 90.13135136130028, "col2": 80.44625317489727, "col3": 22.6043232147787, "col4": 93.40477296593345}, {"categories": "D", "col0": 8.854183492033973, "col1": 93.08511206959147, "col2": 34.172310220681155, "col3": 72.50318223798608, "col4": 59.07520153841682}, {"categories": "E", "col0": 94.34365450014978, "col1": 35.02130986226719, "col2": 54.72099793040287, "col3": 5.855012356539269, "col4": 25.616153554561084}, {"categories": "E", "col0": 31.3163302007912, "col1": 94.37203879424804, "col2": 43.702068017586015, "col3": 54.765061835585946, "col4": 18.655317988093177}, {"categories": "E", "col0": 39.99639850196722, "col1": 87.46614082051879, "col2": 51.176152537308326, "col3": 14.587946006175411, "col4": 38.72964910916236}];var args_2010688838680 = {"keys_0": ["categories"], "values_0": ["col0", "col1"], "chart_0_1": ["col0", "col1"], "chart_1_1": "categories"} ;var ChartBubble_markDownFnc = false;function buildBreadCrum() { var params = [] ; for(var key in breadCrumUrl['params']) { params.push(key + "=" + breadCrumUrl['params'][key]) ;  }var breadCrumResult = breadCrumUrl['url'] ;if (params.length > 0) { breadCrumResult = breadCrumResult + "?" + params.join("&")  ;}return breadCrumResult; ;};function aresObj(htmlCode) { if (htmlCode in breadCrumUrl.params) {return breadCrumUrl.params[htmlCode];} else { return null } ;};function FormatFilterDt(filterVal) { var dt = filterVal.split('-') ; return dt[2] + '/' + dt[1] + '/'+ dt[0] ; ;};function GetClipBoardData(event) { if (window.clipboardData == undefined) { alert('this only works with IE') ; } else { return window.clipboardData.getData('text')}; ;};function LoadingPopup(reportName) { $('#popup_loading').find("div").html("Loading " + reportName + "..."); $('#popup_loading_back').show(); $('#popup_loading').show(); ;};function GoToReport(url, newWindows, widthLoading) { if(newWindows) { window.open(url, '_blank') ; }else {if ( widthLoading ){$('#popup_loading').find("div").html("Loading " + url + "...");$('#popup_loading_back').show(); $('#popup_loading').show(); }window.location.href = url;} ;};function Today() { now = new Date();year = "" + now.getFullYear();month = "" + (now.getMonth() + 1); if (month.length == 1) { month = "0" + month; }day = "" + now.getDate(); if (day.length == 1) { day = "0" + day; }hour = "" + now.getHours(); if (hour.length == 1) { hour = "0" + hour; }minute = "" + now.getMinutes(); if (minute.length == 1) { minute = "0" + minute; }second = "" + now.getSeconds(); if (second.length == 1) { second = "0" + second; }return year + "-" + month + "-" + day + " " + hour + ":" + minute + ":" + second; ;};function CleanText(text) { return text.trim().replace(/\W+/g, ''); ;};function CssStyleBuilder(params) { cssParams = [] ;for( var i in params) { cssParams.push( i +":"+ params[i]) ; }return cssParams.join(";"); ;};function CopyToClipboard() { var url = window.location.href.split('?')[0];if (url.slice(-1) == '#') { url = url.slice(0, -1); };var splitParams = buildBreadCrum().split('?') ; var params = "";if (splitParams.length > 1 ) { params = splitParams.slice(1, splitParams.length); }if (window.clipboardData) { wi ...
